# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import numpy as np
# %matplotlib inline

# %%
data=pd.read_csv("candyhierarchy.csv")
data.iloc[[*range(10), *range(-10, 0)]]
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773            NaN        NaN     NaN         NaN
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# 5        90272852             No       Male     NaN         NaN
# 6        90272853             No       Male      53         usa
# 7        90272854             No       Male      33      canada
# 8        90272858             No       Male      40      Canada
# 9        90272859             No     Female      53          Us
# 2450     90313850             No        NaN     NaN         NaN
# 2451     90313861             No      Other      25         USA
# 2452     90313947             No     Female      43      Canada
# 2453     90313974             No     Female      40      canada
# ...

# %%
#so we are gonna show type the the 10 top from head and tail of dataframe
data.dtypes.iloc[[*range(10), *range(-10, 0)]]
# Out:
# Internal ID                                                                                 int64
# Q1: GOING OUT?                                                                             object
# Q2: GENDER                                                                                 object
# Q3: AGE                                                                                    object
# Q4: COUNTRY                                                                                object
# Q5: STATE, PROVINCE, COUNTY, ETC                                                           object
# Q6 | 100 Grand Bar                                                                         object
# Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)     object
# Q6 | Any full-sized candy bar                                                              object
# Q6 | Black Jacks                                                                           object
# ...
